# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("covid 19 sentiment.csv")

# %%
df.head()
# Out:
#              Timestamp            Name Gender    Age  \
# 0  11/14/2020 14:22:58      Soham Shah   Male  18-30
# 1  11/14/2020 14:35:35  Vivek Chandola   Male  18-30
# 2  11/14/2020 14:39:20    Rishav Ghosh   Male  18-30
# 3  11/14/2020 14:42:27       Saif khan   Male  18-30
# 4  11/14/2020 14:49:47       Md kaisar   Male  18-30
#
#   State or Union Territories Working Status  \
# 0                Maharashtra        Student
# 1                 Uttrakhand        Student
# 2                West Bengal        Student
# 3                  Jharkhand        Student
# 4                  Jharkhand        Student
#
#   How many times you are going for shopping in a day?  \
# 0                                                0-1
# 1                                                0-1
# 2                                                0-1
# 3                                                0-1
# 4                                                0-1
#
# ...

# %%
df=df.drop(["Timestamp"],axis=1)

# %%
df.columns=['Name','Sex','Age','State','Working Status','Shopping','Travelling preference','Re-lockdown','scl-clg','Lockdown at home','Vaccination or Economy','Suggestions','Target']

# %%
df.head()
# Out:
#              Name   Sex    Age        State Working Status Shopping  \
# 0      Soham Shah  Male  18-30  Maharashtra        Student      0-1
# 1  Vivek Chandola  Male  18-30   Uttrakhand        Student      0-1
# 2    Rishav Ghosh  Male  18-30  West Bengal        Student      0-1
# 3       Saif khan  Male  18-30    Jharkhand        Student      0-1
# 4       Md kaisar  Male  18-30    Jharkhand        Student      0-1
#
#   Travelling preference Re-lockdown                                   scl-clg  \
# 0         Happy at home         Yes  After the vaccine is available in market
# 1          Personal Car          No  After the vaccine is available in market
# 2         Happy at home         Yes  After the vaccine is available in market
# 3         Happy at home         Yes  After the vaccine is available in market
# 4         Happy at home         Yes  After the vaccine is available in market
#
#                                     Lockdown at home  \
# ...

# %%
df.isnull().sum()
# Out:
# Name                       7
# Sex                        1
# Age                        6
# State                      2
# Working Status             2
# Shopping                   2
# Travelling preference      1
# Re-lockdown                4
# scl-clg                    1
# Lockdown at home          33
# Vaccination or Economy    24
# Suggestions               73
# Target                     0
# dtype: int64

# %%
df["Suggestions"]=df["Suggestions"].fillna('No Suggestions')
df["Vaccination or Economy"]=df["Vaccination or Economy"].fillna("Vaccination")
df["Lockdown at home"]=df["Lockdown at home"].fillna("No response")
df["Name"]=df["Name"].fillna("Anonimous")
df["scl-clg"]=df["scl-clg"].fillna("After the vaccine is available in market")
df["Re-lockdown"]=df["Re-lockdown"].fillna("No")
df["Travelling preference"]=df["Travelling preference"].fillna("Happy at home")
df["Shopping"]=df["Shopping"].fillna("0-1")
df["Working Status"]=df["Working Status"].fillna("Student")
df["State"]=df["State"].fillna("West Bengal")
df["Age"]=df["Age"].fillna("18-30")
df["Sex"]=df["Sex"].fillna("Male")
df["Target"]=df["Target"].fillna("Positive")

# %%
df.isnull().sum()
# Out:
# Name                      0
# Sex                       0
# Age                       0
# State                     0
# Working Status            0
# Shopping                  0
# Travelling preference     0
# Re-lockdown               0
# scl-clg                   0
# Lockdown at home          0
# Vaccination or Economy    0
# Suggestions               0
# Target                    0
# dtype: int64

# %%
df.shape
# Out:
# (201, 13)

# %%
df["Review"]=df["Travelling preference"]+' '+df["Re-lockdown"]+" "+df["scl-clg"]+" "+df["Lockdown at home"]+" "+df["Vaccination or Economy"]+" "+df["Suggestions"]

# %% [markdown]
# independent feature

# %%
X=df.drop('Target',axis=1)
X.head()
# Out:
#              Name   Sex    Age        State Working Status Shopping  \
# 0      Soham Shah  Male  18-30  Maharashtra        Student      0-1
# 1  Vivek Chandola  Male  18-30   Uttrakhand        Student      0-1
# 2    Rishav Ghosh  Male  18-30  West Bengal        Student      0-1
# 3       Saif khan  Male  18-30    Jharkhand        Student      0-1
# 4       Md kaisar  Male  18-30    Jharkhand        Student      0-1
#
#   Travelling preference Re-lockdown                                   scl-clg  \
# 0         Happy at home         Yes  After the vaccine is available in market
# 1          Personal Car          No  After the vaccine is available in market
# 2         Happy at home         Yes  After the vaccine is available in market
# 3         Happy at home         Yes  After the vaccine is available in market
# 4         Happy at home         Yes  After the vaccine is available in market
#
#                                     Lockdown at home  \
# ...

# %%
X.shape
# Out:
# (201, 13)

# %%
Y=df['Target']
Y.shape
# Out:
# (201,)

# %%
Y.head()
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# Name: Target, dtype: object

# %%
from sklearn import preprocessing
df["Target"]=label_encoder.fit_transform(df['Target'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-5df07e3e8981> in <module>
#       1 from sklearn import preprocessing
# ----> 2 df["Target"]=label_encoder.fit_transform(df['Target'])
#
# NameError: name 'label_encoder' is not defined

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
Y=df['Target']

# %%
##y=pd.get_dummies(Y,drop_first=True)
##y.head()dww

# %%
X.shape

# %%
Y.shape
# Out:
# (201,)

# %% [markdown]
# INDEPENDENT FEATURE

# %% [markdown]
# DEPENDENT FEATURE

# %%
df.head()
# Out:
#              Name   Sex    Age        State Working Status Shopping  \
# 0      Soham Shah  Male  18-30  Maharashtra        Student      0-1
# 1  Vivek Chandola  Male  18-30   Uttrakhand        Student      0-1
# 2    Rishav Ghosh  Male  18-30  West Bengal        Student      0-1
# 3       Saif khan  Male  18-30    Jharkhand        Student      0-1
# 4       Md kaisar  Male  18-30    Jharkhand        Student      0-1
#
#   Travelling preference Re-lockdown                                   scl-clg  \
# 0         Happy at home         Yes  After the vaccine is available in market
# 1          Personal Car          No  After the vaccine is available in market
# 2         Happy at home         Yes  After the vaccine is available in market
# 3         Happy at home         Yes  After the vaccine is available in market
# 4         Happy at home         Yes  After the vaccine is available in market
#
#                                     Lockdown at home  \
# ...

# %%
import tensorflow as tf
# Out:
# d:\users\download\anaconda3\envs\essay\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# d:\users\download\anaconda3\envs\essay\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# d:\users\download\anaconda3\envs\essay\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

# %%
voc_size=5000

# %% [markdown]
# ONE HOT  REPRESENTATION

# %%
messages=X.copy()

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
messages['Review'].head(2)
# Out:
# 0    Happy at home Yes After the vaccine is availab...
# 1    Personal Car No After the vaccine is available...
# Name: Review, dtype: object

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
corpus=[]
for i in range(0,len(messages)):
    

    review=re.sub('[^a-zA-Z]',' ',messages['Review'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if word not in stopwords.words('english')]
 
    review = ' '.join(review)
    corpus.append(review)

# %% [markdown]
# removal of stopwords

# %%
corpus
# Out:
# ['happi home ye vaccin avail market attend onlin virtual lectur cours vaccin suggest',
#  'person car vaccin avail market learn new thing like cook code garden also netflix play ludo mani indoor game vaccin suggest',
#  'happi home ye vaccin avail market respons suggest',
#  'happi home ye vaccin avail market ye spent time famili play valleybal home exercis side vaccin first peopl healthi increas economi exam taken onlin mode help decreas viru impact',
#  'happi home ye vaccin avail market play game vaccin increas awar protect covid',
#  'train colleg open school watch prime netflix noth want honest work govt govt bluff peopl india',
#  'happi home ye vaccin avail market learn someth new economi suggest',
#  'flight ye vaccin avail market studi play indoor game learn new skill vaccin would first prioriti economi grow tighten law chanc flaw',
#  'flight vaccin avail market respons vaccin suggest',
# ...

# %%
onehot_repr=[one_hot(words,voc_size)for words in corpus]
onehot_repr
# Out:
# [[3641, 2698, 3404, 659, 2783, 718, 2098, 365, 3401, 1264, 3749, 659, 158],
#  [3659,
#   4755,
#   659,
#   2783,
#   718,
#   181,
#   554,
#   3579,
#   4784,
#   1085,
#   329,
#   1400,
#   948,
#   4095,
#   2296,
#   4221,
#   1307,
#   4412,
#   425,
#   659,
#   158],
#  [3641, 2698, 3404, 659, 2783, 718, 3241, 158],
#  [3641,
#   2698,
#   3404,
#   659,
#   2783,
#   718,
#   3404,
#   1831,
#   968,
#   953,
#   2296,
#   230,
#   2698,
#   4029,
#   3182,
#   659,
#   3730,
#   2832,
#   3909,
#   4364,
#   192,
#   149,
#   4460,
#   365,
#   3148,
#   3209,
#   2791,
#   1268,
#   1718],
#  [3641, 2698, 3404, 659, 2783, 718, 2296, 425, 659, 4364, 4916, 4263, 1072],
#  [3891,
#   2819,
#   4699,
#   2032,
#   813,
#   2817,
#   4095,
#   3919,
#   486,
#   3708,
#   4012,
#   3175,
#   3175,
#   1794,
#   2832,
#   877],
#  [3641, 2698, 3404, 659, 2783, 718, 181, 2525, 554, 192, 158],
#  [513,
#   3404,
#   659,
#   2783,
#   718,
#   2852,
#   2296,
#   4412,
#   425,
# ...

# %% [markdown]
# Embedding Representation

# %%
sent_length=15
embedded_doc=pad_sequences(onehot_repr,padding='post',maxlen=sent_length)

# %%
print(embedded_doc[0])
len(embedded_doc)
# Out:
# [3641 2698 3404  659 2783  718 2098  365 3401 1264 3749  659  158    0
#     0]
# 201

# %%
len(embedded_doc)
# Out:
# 201

# %% [markdown]
# **creating model**

# %%
import numpy as np
X_final=np.array(embedded_doc)
Y_final=np.array(Y)

# %%
X_final
# Out:
# array([[3641, 2698, 3404, ...,  158,    0,    0],
#        [ 554, 3579, 4784, ...,  425,  659,  158],
#        [3641, 2698, 3404, ...,    0,    0,    0],
#        ...,
#        [ 239, 1147, 1009, ..., 2832, 3548, 2902],
#        [3641, 2698, 3404, ...,    0,    0,    0],
#        [3659, 4755, 3939, ...,  358,    0,    0]])

# %%
Y_final
# Out:
# array(['Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Negative', 'Neutral', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Neutral', 'Positive', 'Positive',
#        'Negative', 'Positive', 'Negative', 'Negative', 'Negative',
#        'Negative', 'Neutral', 'Negative', 'Positive', 'Neutral',
#        'Positive', 'Positive', 'Negative', 'Positive', 'Negative',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Negative',
#        'Positive', 'Positive', 'Negative', 'Positive', 'Negative',
#        'Positive', 'Neutral', 'Neutral', 'Negative', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Neutral', 'Positive',
#        'Negative', 'Negative', 'Neutral', 'Positive', 'Positive',
#        'Neutral', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Negative', 'Neutral', 'Negative', 'Neutral',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
# ...

# %%
# !pip install -U keras-tuner

# %%
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-54-7bb571729a7c> in <module>
#       1 from tensorflow import keras
#       2 from tensorflow.keras import layers
# ----> 3 from kerastuner.tuners import RandomSearch
#
# ModuleNotFoundError: No module named 'kerastuner'

# %%
import tensorflow as tf
from tensorflow import keras

# %%
# !pip install -q -U keras-tuner
import kerastuner as kt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-5d7b6944a6ac> in <module>
#       1 get_ipython().system('pip install -q -U keras-tuner')
# ----> 2 import kerastuner as kt
#
# ModuleNotFoundError: No module named 'kerastuner'

# %%
# !pip install tensorflow==2.1

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 100)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-7a9def489967> in <module>
# ----> 1 tuner = RandomSearch(
#       2     build_model,
#       3     objective='val_accuracy',
#       4     max_trials=5,
#       5     executions_per_trial=3,
#
# NameError: name 'RandomSearch' is not defined

# %%
epochs=50
batch_size=64

# %%
from tensorflow.keras.layers import Dropout
embedding_vector_feature=30
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_feature,input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy' ,optimizer="adam",metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_19 (Embedding)     (None, 15, 30)            150000
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 15, 30)            0
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 100)               52400
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 100)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 101
# ...
# Total params: 202,501
# Trainable params: 202,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#from sklearn.model_selection import train_test_split
#X_train,X_test,Y_train,Y_test=train_test_split(X_final,Y_final,test_size=0.2,random_state=0)

# %%
history=model.fit(X_final,Y_final,epochs=epochs,verbose=1,batch_size=batch_size)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 1s 178ms/step - loss: 0.6777 - accuracy: 0.2313 - val_loss: 0.6343 - val_accuracy: 0.1220
# Epoch 2/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.6224 - accuracy: 0.1813 - val_loss: 0.5615 - val_accuracy: 0.1220
# Epoch 3/50
# 3/3 [==============================] - 0s 19ms/step - loss: 0.5485 - accuracy: 0.1813 - val_loss: 0.4444 - val_accuracy: 0.1220
# Epoch 4/50
# 3/3 [==============================] - 0s 20ms/step - loss: 0.4184 - accuracy: 0.1813 - val_loss: 0.2263 - val_accuracy: 0.1220
# Epoch 5/50
# 3/3 [==============================] - 0s 21ms/step - loss: 0.1803 - accuracy: 0.1813 - val_loss: -0.2272 - val_accuracy: 0.1220
# Epoch 6/50
# 3/3 [==============================] - 0s 19ms/step - loss: -0.3437 - accuracy: 0.1813 - val_loss: -1.1871 - val_accuracy: 0.1220
# Epoch 7/50
# ...

# %%
print(model.summary)
# Out:
# <bound method Model.summary of <tensorflow.python.keras.engine.sequential.Sequential object at 0x7f035a8ff9e8>>

# %%
X_train.dtype
# Out:
# dtype('int32')

# %%
y_train.dtype
# Out:
# dtype('uint8')
